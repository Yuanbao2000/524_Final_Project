# %% [markdown]
# ### CS/ECE/ISyE 524 &mdash; Introduction to Optimization &mdash; Spring 2026 ###
#
# # GPU Task Scheduling Optimization #
#
# #### Xuechun Jin (xjin252@wisc.edu), Student 2 (email address), Student 3 (email address)
#
# ### Table of Contents
#
# 1. [Introduction](#1.-Introduction)
# 1. [Mathematical Model](#2.-Mathematical-model)
# 1. [Implementation and Solution](#3.-Implementation)
# 1. [Discussion of Results](#4.-Results-discussion)
# 1. [Optional Subsection](#4.A.-Feel-free-to-add-subsections)
# 1. [Conclusion](#5.-Conclusion)

# %% [markdown]
# ## 1. Introduction ##

# %% [markdown]
# Our project aims to improve GPU task scheduling by building optimization models. It includes a basic model and an extended model, both formulated as MILP models. We aim to improve the overall system performance by efficiently assigning tasks to limited GPU resources. Under different settings, we aim to minimize the total completion time when all tasks must be executed, and maximize the total task value within a limited time when tasks can be skipped.

# %% [markdown]
# In our basic model, we have 20 tasks and 4 identical GPUs. Each task has two possible configurations, each specifying the number of GPUs required and the runtime to complete the task. For example, a task can take 24 minutes when using one GPU, but might only need 14 minutes when running on two. Each task can choose only one configuration, and all tasks must be executed. We present the execution order by assigning a start time and a finish time to each task, and we ensure that the total number of GPUs in use does not exceed 4 at any time. Our goal is to choose the best configuration combination and the order of executing tasks to minimize the total completion time.

# %% [markdown]
# In the extended model, each task is assigned a value to represent its priority. A higher value means a higher priority. Unlike the basic model, tasks are not required to be executed, and some tasks can be skipped as needed. In addition, there is a total execution time budget now. Our goal is to select a subset of tasks and their execution order to maximize the total value of completed tasks within the time limit.

# %% [markdown]
# Mordern GPUs are widely used in large-scale computing. However, once a GPU task starts running, it usually cannot be interrupted. When multiple applications share the same GPU, important tasks may be delayed for a long time. Therefore, It is important to schedule tasks properly so that high-value tasks can be completed as early as possible. This can improve the overall system performance and make better use of expensive GPU resoueces. An early work, TimeGraph [1], propoeses a GPU scheduling method that uses task priorities to decide the execution order, with a max running time constraint to prevent one task from abusing resources. However, for simplicity, we do not consider the execution time limits in our project. Another recent work introduces the operation of a shared GPU cluster on HKUST campus [2]. GPUs are offered in packs of 1, 2, 4, and 8. While this strategy mitigates the fragmentation issues, it losses some scheduling flexibility and assumes a decent cluster.

# %% [markdown]
# We do not use real data for this project. Instead, we generate synthetic data for GPU requirements, runtime, and task values. We also consider the following assumptions to simplify our models:
#  - All GPUs are identical and can run tasks at the same time.
#  - Tasks are independent from each other.
#  - Tasks cannot be interrupted once it starts execution.
#  - Each task can only choose one given configuration.
#  - All tasks must be executed in the basic model.
#  - Tasks can be skipped in the extended model.

# %% [markdown]
# outline here! (write the entire report first then go back to write this part)

# %% [markdown]
# ## 2. Mathematical model ##

# %% [markdown]
# ## 2.A Basic Model ##

# %% [markdown]
# **Data:**
#  - $p_{ik}$ is the running time for task $i$ with consiguration $k$
#  - $g_{ik}$ is the required number of GPUs for task $i$ with consiguration $k$
#  - $G$ is the total number of GPU
#  - $N$ is the total number of tasks
#  - $H$ is the upper bound of the total completion time: $H = \sum_{i = 1}^{N} \max_{k \in \{1, 2\}} p_{ik}$

# %% [markdown]
# **Decision variables:**
#
# 1. For the configuration selection and the task start time:
#  - $$
#     x_{ikt} = \begin{cases}
#     1, \quad\text{if task $i$ starts at time $t$ with configuration $k$} \\
#     0, \quad\text{otherwise}
#     \end{cases} \quad \forall i \in \{1, 2,..., N\}, k \in \{1, 2\}, t \in \{0, 1,..., H - p_{ik}\}
#     $$
#
# 2. To evaluate the results, we define:
#  - $C$ is the total completion time (makespan) for all tasks.

# %% [markdown]
# **Objective：**
#
# Our objective is to minimize the makespan C:
#  - $\min C$

# %% [markdown]
# **Constraints:**
#
# 1. Each task has to choose exactly one configuration (means all tasks must be executed):
#  - $\sum_{k \in \{1, 2\}}\sum_{t = 0}^{H - p_{ik}} x_{ikt} = 1 \quad \forall i \in \{1, 2,..., N\}$
# 2. The total number of GPUs in use does not exceed 4 at any time point $r$.
#  - $\sum_{i = 1}^{N} \sum_{k \in \{1, 2\}} \sum_{t \le r \le t + p_{ik} - 1} g_{ik}x_{ikt} \le G \quad \forall r \in \{0, 1,..., H\}$
# 3. Makespan C must be greater than the completion time of every single tasks:
#  - $C \ge \sum_{k \in \{1, 2\}} \sum_{t = 0}^{H - p_{ik}} (t + p_{ik})x_{ikt} \quad \forall i \in \{1, 2,..., N\}$
# 4. Non-negativity:
#  - $x_{ikt} \ge 0$
#  - $C \ge 0$

# %% [markdown]
# **The full model in standard form:**
# $$
# \begin{aligned}
# \max -C \\
# \text{subject to} \quad
# & \sum_{k \in \{1, 2\}}\sum_{t = 0}^{H - p_{ik}} x_{ikt} \le 1 \quad \forall i \in \{1, 2,..., N\}\\
# & -\sum_{k \in \{1, 2\}}\sum_{t = 0}^{H - p_{ik}} x_{ikt} \le -1 \quad \forall i \in \{1, 2,..., N\}\\
# & \sum_{i = 1}^{N} \sum_{k \in \{1, 2\}} \sum_{t \le r \le t + p_{ik} - 1} g_{ik}x_{ikt} \le G \quad \forall r \in \{0, 1,..., H\}\\
# & \sum_{k \in \{1, 2\}} \sum_{t = 0}^{H - p_{ik}} (t + p_{ik})x_{ikt} \le C \quad \forall i \in \{1, 2,..., N\}\\
# & x_{ikt} \ge 0, C \ge 0\\
# \end{aligned}
# $$

# %% [markdown]
# ## 2.B Extended Model ##

# %% [markdown]
# **Data:**
#  - $p_{ik}$ is the running time for task $i$ with consiguration $k$
#  - $g_{ik}$ is the required number of GPUs for task $i$ with consiguration $k$
#  - $G$ is the total number of GPU
#  - $N$ is the total number of tasks
#  - $L$ is the given time limit
#  - $v_i$ is the given task value for task $i$

# %% [markdown]
# **Decision variables:**
#
# 1. For the configuration selection and the task start time:
#  - $$
#     x_{ikt} = \begin{cases}
#     1, \quad\text{if task $i$ starts at time $t$ with configuration $k$} \\
#     0, \quad\text{otherwise}
#     \end{cases} \quad \forall i \in \{1, 2,..., N\}, k \in \{1, 2\}, t \in \{0, 1,..., L - p_{ik}\}
#     $$

# %% [markdown]
# **Objective：**
#
# Our objective is to maximize the total executed task value:
#  - $\max \sum_{i = 1}^{N} \sum_{k \in \{1, 2\}}\sum_{t = 0}^{L - p_{ik}} v_ix_{ikt}$

# %% [markdown]
# **Constraints:**
#
# 1. Each task can choose at most one configuration (tasks can be skipped):
#  - $\sum_{k \in \{1, 2\}}\sum_{t = 0}^{L - p_{ik}} x_{ikt} \le 1 \quad \forall i \in \{1, 2,..., N\}$
# 2. The total number of GPUs in use does not exceed 4 at any time point $r$:
#  - $\sum_{i = 1}^{N} \sum_{k \in \{1, 2\}} \sum_{t \le r \le t + p_{ik} - 1} g_{ik}x_{ikt} \le G \quad \forall r \in \{0, 1,..., L\}$
# 3. The completion time of all executed tasks cannot exceed L: Since we change the range of $t$ to $[0, L - p_{ik}]$, this requirement is met automatically.
# 4. Non-negativity:
#  - $x_{ikt} \ge 0$

# %% [markdown]
# **The full model in standard form:**
# $$
# \begin{aligned}
# \max \sum_{i = 1}^{N} \sum_{k \in \{1, 2\}}\sum_{t = 0}^{L - p_{ik}} v_ix_{ikt} \\
# \text{subject to} \quad
# & \sum_{k \in \{1, 2\}}\sum_{t = 0}^{L - p_{ik}} x_{ikt} \le 1 \quad \forall i \in \{1, 2,..., N\}\\\
# & \sum_{i = 1}^{N} \sum_{k \in \{1, 2\}} \sum_{t \le r \le t + p_{ik} - 1} g_{ik}x_{ikt} \le G \quad \forall r \in \{0, 1,..., L\}\\
# & x_{ikt} \ge 0\\
# \end{aligned}
# $$

# %% [markdown]
# ## 3. Implementation \& Solutions ##

# %% [markdown]
# ## 3.A Data Generation ##

# %%
using JuMP, HiGHS, Random
# data generated are the same everytime
Random.seed!(1218)

# the number of GPUs
G = 4
# the number of tasks
N = 20
# p is the running time. Configurations with more GPUs run faster
# so config 1 needs 1 GPU, runtime is between 10 to 30 minutes
# config 2 needs 2 GPUs, runtime is between 5 to 5 minutes less than the runtime of config 1
p = zeros(Int, N, 2)
for i in 1:N
    p[i, 1] = rand(15:30)
    p[i, 2] = rand(5:p[i, 1]-5)
end
# g: reuqired number of GPUs for config 1 and 2
g = ones(Int, N, 2)
g[:, 2] .= 2
# H: the upperbound
H = sum(maximum(p[i, :]) for i in 1:N)
# Out:
# 451

# %%
# print out the data
println(p)
println(g)
# Out:
# [24 14; 15 5; 27 6; 21 6; 23 16; 15 9; 25 9; 26 11; 18 12; 18 13; 27 9; 19 5; 26 17; 23 15; 26 11; 18 7; 25 9; 25 17; 30 23; 20 9]
# [1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2; 1 2]

# %% [markdown]
# To make the data more clear, we present it as the following table. Config 1 requires 1 GPU and Config 2 requires 2 GPUs.

# %% [markdown]
# | Task | Config 1 Runtime (mins) | Config 2 Runtime (mins) |
# |-----:|------------------------:|------------------------:|
# | 1    | 24                      | 14                      |
# | 2    | 15                      | 5                       |
# | 3    | 27                      | 6                       |
# | 4    | 21                      | 6                       |
# | 5    | 23                      | 16                      |
# | 6    | 15                      | 9                       |
# | 7    | 25                      | 9                       |
# | 8    | 26                      | 11                      |
# | 9    | 18                      | 12                      |
# | 10   | 18                      | 13                      |
# | 11   | 27                      | 9                       |
# | 12   | 19                      | 5                       |
# | 13   | 26                      | 17                      |
# | 14   | 23                      | 15                      |
# | 15   | 26                      | 11                      |
# | 16   | 18                      | 7                       |
# | 17   | 25                      | 9                       |
# | 18   | 25                      | 17                      |
# | 19   | 30                      | 23                      |
# | 20   | 20                      | 9                       |

# %% [markdown]
# ## 3.B Code for the Basic Model ##

# %%
m = Model(HiGHS.Optimizer)

# define x_ikt as a binary variable
@variable(m, x[i = 1:N, k = 1:2, t = 0:H - p[i,k]], Bin)  
@variable(m, C >= 0)  

@objective(m, Min, C) 
   
# each task has to choose exactly one configuration
@constraint(m, config[i in 1:N], sum(x[i, k, t] for k in 1:2, t in 0:H - p[i,k]) == 1)  
# the total number of GPUs in use does not exceed 4 at anytime
# t cannot be less than 0
@constraint(m, gpu[r in 0:H], sum(g[i, k]*x[i, k, t] 
        for i in 1:N, k in 1:2, t in max(0, r - p[i, k] + 1):min(r, H - p[i,k])) <= G)  
# makespan C must be greater than the completion time of every single tasks
@constraint(m, makespan[i in 1:N], sum((t + p[i, k])*x[i, k, t] for k in 1:2, t in 0:H - p[i,k]) <= C)  

# run optimizer
set_silent(m)
optimize!(m)


# print the results
println("The optimal result (Min makespan): ", objective_value(m), " mins.") 
for i in 1:N
    for k in 1:2
        for t in 0:H-p[i,k]
            # only print out the configs that are selected
            # we use > 0.9 instead of == 1 because sometimes the solver returns 0.999999
            if value(x[i, k, t]) > 0.9
                println("Task $i uses config $k, start time is $t, finish time = $(t + p[i, k])")
            end
        end
    end
end
# Out:
# The optimal result (Min makespan): 94.0 mins.
# Task 1 uses config 1, start time is 0, finish time = 24
# Task 1 uses config 1, start time is 1, finish time = 25
# Task 1 uses config 1, start time is 2, finish time = 26
# Task 1 uses config 1, start time is 3, finish time = 27
# Task 1 uses config 1, start time is 4, finish time = 28
# Task 1 uses config 1, start time is 5, finish time = 29
# Task 1 uses config 1, start time is 6, finish time = 30
# Task 1 uses config 1, start time is 7, finish time = 31
# Task 1 uses config 1, start time is 8, finish time = 32
# Task 1 uses config 1, start time is 9, finish time = 33
# Task 1 uses config 1, start time is 10, finish time = 34
# Task 1 uses config 1, start time is 11, finish time = 35
# Task 1 uses config 1, start time is 12, finish time = 36
# Task 1 uses config 1, start time is 13, finish time = 37
# Task 1 uses config 1, start time is 14, finish time = 38
# Task 1 uses config 1, start time is 15, finish time = 39
# Task 1 uses config 1, start time is 16, finish time = 40
# Task 1 uses config 1, start time is 17, finish time = 41
# Task 1 uses config 1, start time is 18, finish time = 42
# Task 1 uses config 1, start time is 19, finish time = 43
# Task 1 uses config 1, start time is 20, finish time = 44
# Task 1 uses config 1, start time is 21, finish time = 45
# Task 1 uses config 1, start time is 22, finish time = 46
# Task 1 uses config 1, start time is 23, finish time = 47
# Task 1 uses config 1, start time is 24, finish time = 48
# Task 1 uses config 1, start time is 25, finish time = 49
# Task 1 uses config 1, start time is 26, finish time = 50
# Task 1 uses config 1, start time is 27, finish time = 51
# Task 1 uses config 1, start time is 28, finish time = 52
# Task 1 uses config 1, start time is 29, finish time = 53
# Task 1 uses config 1, start time is 30, finish time = 54
# Task 1 uses config 1, start time is 31, finish time = 55
# Task 1 uses config 1, start time is 32, finish time = 56
# Task 1 uses config 1, start time is 33, finish time = 57
# Task 1 uses config 1, start time is 34, finish time = 58
# Task 1 uses config 1, start time is 35, finish time = 59
# Task 1 uses config 1, start time is 36, finish time = 60
# Task 1 uses config 1, start time is 37, finish time = 61
# Task 1 uses config 1, start time is 38, finish time = 62
# Task 1 uses config 1, start time is 39, finish time = 63
# Task 1 uses config 1, start time is 40, finish time = 64
# Task 1 uses config 1, start time is 41, finish time = 65
# Task 1 uses config 1, start time is 42, finish time = 66
# Task 1 uses config 1, start time is 43, finish time = 67
# Task 1 uses config 1, start time is 44, finish time = 68
# Task 1 uses config 1, start time is 45, finish time = 69
# Task 1 uses config 1, start time is 46, finish time = 70
# Task 1 uses config 1, start time is 47, finish time = 71
# Task 1 uses config 1, start time is 48, finish time = 72
# Task 1 uses config 1, start time is 49, finish time = 73
# Task 1 uses config 1, start time is 50, finish time = 74
# Task 1 uses config 1, start time is 51, finish time = 75
# Task 1 uses config 1, start time is 52, finish time = 76
# Task 1 uses config 1, start time is 53, finish time = 77
# Task 1 uses config 1, start time is 54, finish time = 78
# Task 1 uses config 1, start time is 55, finish time = 79
# Task 1 uses config 1, start time is 56, finish time = 80
# Task 1 uses config 1, start time is 57, finish time = 81
# Task 1 uses config 1, start time is 58, finish time = 82
# Task 1 uses config 1, start time is 59, finish time = 83
# Task 1 uses config 1, start time is 60, finish time = 84
# Task 1 uses config 1, start time is 61, finish time = 85
# Task 1 uses config 1, start time is 62, finish time = 86
# Task 1 uses config 1, start time is 63, finish time = 87
# Task 1 uses config 1, start time is 64, finish time = 88
# Task 1 uses config 1, start time is 65, finish time = 89
# Task 1 uses config 1, start time is 66, finish time = 90
# Task 1 uses config 1, start time is 67, finish time = 91
# Task 1 uses config 1, start time is 68, finish time = 92
# Task 1 uses config 1, start time is 69, finish time = 93
# Task 1 uses config 1, start time is 70, finish time = 94
# Task 1 uses config 1, start time is 71, finish time = 95
# Task 1 uses config 1, start time is 72, finish time = 96
# Task 1 uses config 1, start time is 73, finish time = 97
# Task 1 uses config 1, start time is 74, finish time = 98
# Task 1 uses config 1, start time is 75, finish time = 99
# Task 1 uses config 1, start time is 76, finish time = 100
# Task 1 uses config 1, start time is 77, finish time = 101
# Task 1 uses config 1, start time is 78, finish time = 102
# Task 1 uses config 1, start time is 79, finish time = 103
# Task 1 uses config 1, start time is 80, finish time = 104
# Task 1 uses config 1, start time is 81, finish time = 105
# Task 1 uses config 1, start time is 82, finish time = 106
# Task 1 uses config 1, start time is 83, finish time = 107
# Task 1 uses config 1, start time is 84, finish time = 108
# Task 1 uses config 1, start time is 85, finish time = 109
# Task 1 uses config 1, start time is 86, finish time = 110
# Task 1 uses config 1, start time is 87, finish time = 111
# Task 1 uses config 1, start time is 88, finish time = 112
# Task 1 uses config 1, start time is 89, finish time = 113
# Task 1 uses config 1, start time is 90, finish time = 114
# Task 1 uses config 1, start time is 91, finish time = 115
# Task 1 uses config 1, start time is 92, finish time = 116
# Task 1 uses config 1, start time is 93, finish time = 117
# Task 1 uses config 1, start time is 94, finish time = 118
# Task 1 uses config 1, start time is 95, finish time = 119
# Task 1 uses config 1, start time is 96, finish time = 120
# Task 1 uses config 1, start time is 97, finish time = 121
# Task 1 uses config 1, start time is 98, finish time = 122
# Task 1 uses config 1, start time is 99, finish time = 123
# Task 1 uses config 1, start time is 100, finish time = 124
# Task 1 uses config 1, start time is 101, finish time = 125
# Task 1 uses config 1, start time is 102, finish time = 126
# Task 1 uses config 1, start time is 103, finish time = 127
# Task 1 uses config 1, start time is 104, finish time = 128
# Task 1 uses config 1, start time is 105, finish time = 129
# Task 1 uses config 1, start time is 106, finish time = 130
# Task 1 uses config 1, start time is 107, finish time = 131
# Task 1 uses config 1, start time is 108, finish time = 132
# Task 1 uses config 1, start time is 109, finish time = 133
# Task 1 uses config 1, start time is 110, finish time = 134
# Task 1 uses config 1, start time is 111, finish time = 135
# Task 1 uses config 1, start time is 112, finish time = 136
# Task 1 uses config 1, start time is 113, finish time = 137
# Task 1 uses config 1, start time is 114, finish time = 138
# Task 1 uses config 1, start time is 115, finish time = 139
# Task 1 uses config 1, start time is 116, finish time = 140
# Task 1 uses config 1, start time is 117, finish time = 141
# Task 1 uses config 1, start time is 118, finish time = 142
# Task 1 uses config 1, start time is 119, finish time = 143
# Task 1 uses config 1, start time is 120, finish time = 144
# Task 1 uses config 1, start time is 121, finish time = 145
# Task 1 uses config 1, start time is 122, finish time = 146
# Task 1 uses config 1, start time is 123, finish time = 147
# Task 1 uses config 1, start time is 124, finish time = 148
# Task 1 uses config 1, start time is 125, finish time = 149
# Task 1 uses config 1, start time is 126, finish time = 150
# Task 1 uses config 1, start time is 127, finish time = 151
# Task 1 uses config 1, start time is 128, finish time = 152
# Task 1 uses config 1, start time is 129, finish time = 153
# Task 1 uses config 1, start time is 130, finish time = 154
# Task 1 uses config 1, start time is 131, finish time = 155
# Task 1 uses config 1, start time is 132, finish time = 156
# Task 1 uses config 1, start time is 133, finish time = 157
# Task 1 uses config 1, start time is 134, finish time = 158
# Task 1 uses config 1, start time is 135, finish time = 159
# Task 1 uses config 1, start time is 136, finish time = 160
# Task 1 uses config 1, start time is 137, finish time = 161
# Task 1 uses config 1, start time is 138, finish time = 162
# Task 1 uses config 1, start time is 139, finish time = 163
# Task 1 uses config 1, start time is 140, finish time = 164
# Task 1 uses config 1, start time is 141, finish time = 165
# Task 1 uses config 1, start time is 142, finish time = 166
# Task 1 uses config 1, start time is 143, finish time = 167
# Task 1 uses config 1, start time is 144, finish time = 168
# Task 1 uses config 1, start time is 145, finish time = 169
# Task 1 uses config 1, start time is 146, finish time = 170
# Task 1 uses config 1, start time is 147, finish time = 171
# Task 1 uses config 1, start time is 148, finish time = 172
# Task 1 uses config 1, start time is 149, finish time = 173
# Task 1 uses config 1, start time is 150, finish time = 174
# Task 1 uses config 1, start time is 151, finish time = 175
# Task 1 uses config 1, start time is 152, finish time = 176
# Task 1 uses config 1, start time is 153, finish time = 177
# Task 1 uses config 1, start time is 154, finish time = 178
# Task 1 uses config 1, start time is 155, finish time = 179
# Task 1 uses config 1, start time is 156, finish time = 180
# Task 1 uses config 1, start time is 157, finish time = 181
# Task 1 uses config 1, start time is 158, finish time = 182
# Task 1 uses config 1, start time is 159, finish time = 183
# Task 1 uses config 1, start time is 160, finish time = 184
# Task 1 uses config 1, start time is 161, finish time = 185
# Task 1 uses config 1, start time is 162, finish time = 186
# Task 1 uses config 1, start time is 163, finish time = 187
# Task 1 uses config 1, start time is 164, finish time = 188
# Task 1 uses config 1, start time is 165, finish time = 189
# Task 1 uses config 1, start time is 166, finish time = 190
# Task 1 uses config 1, start time is 167, finish time = 191
# Task 1 uses config 1, start time is 168, finish time = 192
# Task 1 uses config 1, start time is 169, finish time = 193
# Task 1 uses config 1, start time is 170, finish time = 194
# Task 1 uses config 1, start time is 171, finish time = 195
# Task 1 uses config 1, start time is 172, finish time = 196
# Task 1 uses config 1, start time is 173, finish time = 197
# Task 1 uses config 1, start time is 174, finish time = 198
# Task 1 uses config 1, start time is 175, finish time = 199
# Task 1 uses config 1, start time is 176, finish time = 200
# Task 1 uses config 1, start time is 177, finish time = 201
# Task 1 uses config 1, start time is 178, finish time = 202
# Task 1 uses config 1, start time is 179, finish time = 203
# Task 1 uses config 1, start time is 180, finish time = 204
# Task 1 uses config 1, start time is 181, finish time = 205
# Task 1 uses config 1, start time is 182, finish time = 206
# Task 1 uses config 1, start time is 183, finish time = 207
# Task 1 uses config 1, start time is 184, finish time = 208
# Task 1 uses config 1, start time is 185, finish time = 209
# Task 1 uses config 1, start time is 186, finish time = 210
# Task 1 uses config 1, start time is 187, finish time = 211
# Task 1 uses config 1, start time is 188, finish time = 212
# Task 1 uses config 1, start time is 189, finish time = 213
# Task 1 uses config 1, start time is 190, finish time = 214
# Task 1 uses config 1, start time is 191, finish time = 215
# Task 1 uses config 1, start time is 192, finish time = 216
# Task 1 uses config 1, start time is 193, finish time = 217
# Task 1 uses config 1, start time is 194, finish time = 218
# Task 1 uses config 1, start time is 195, finish time = 219
# Task 1 uses config 1, start time is 196, finish time = 220
# Task 1 uses config 1, start time is 197, finish time = 221
# Task 1 uses config 1, start time is 198, finish time = 222
# Task 1 uses config 1, start time is 199, finish time = 223
# Task 1 uses config 1, start time is 200, finish time = 224
# Task 1 uses config 1, start time is 201, finish time = 225
# Task 1 uses config 1, start time is 202, finish time = 226
# Task 1 uses config 1, start time is 203, finish time = 227
# Task 1 uses config 1, start time is 204, finish time = 228
# Task 1 uses config 1, start time is 205, finish time = 229
# Task 1 uses config 1, start time is 206, finish time = 230
# Task 1 uses config 1, start time is 207, finish time = 231
# Task 1 uses config 1, start time is 208, finish time = 232
# Task 1 uses config 1, start time is 209, finish time = 233
# Task 1 uses config 1, start time is 210, finish time = 234
# Task 1 uses config 1, start time is 211, finish time = 235
# Task 1 uses config 1, start time is 212, finish time = 236
# Task 1 uses config 1, start time is 213, finish time = 237
# Task 1 uses config 1, start time is 214, finish time = 238
# Task 1 uses config 1, start time is 215, finish time = 239
# Task 1 uses config 1, start time is 216, finish time = 240
# Task 1 uses config 1, start time is 217, finish time = 241
# Task 1 uses config 1, start time is 218, finish time = 242
# Task 1 uses config 1, start time is 219, finish time = 243
# Task 1 uses config 1, start time is 220, finish time = 244
# Task 1 uses config 1, start time is 221, finish time = 245
# Task 1 uses config 1, start time is 222, finish time = 246
# Task 1 uses config 1, start time is 223, finish time = 247
# Task 1 uses config 1, start time is 224, finish time = 248
# Task 1 uses config 1, start time is 225, finish time = 249
# Task 1 uses config 1, start time is 226, finish time = 250
# Task 1 uses config 1, start time is 227, finish time = 251
# Task 1 uses config 1, start time is 228, finish time = 252
# Task 1 uses config 1, start time is 229, finish time = 253
# Task 1 uses config 1, start time is 230, finish time = 254
# Task 1 uses config 1, start time is 231, finish time = 255
# Task 1 uses config 1, start time is 232, finish time = 256
# Task 1 uses config 1, start time is 233, finish time = 257
# Task 1 uses config 1, start time is 234, finish time = 258
# Task 1 uses config 1, start time is 235, finish time = 259
# Task 1 uses config 1, start time is 236, finish time = 260
# Task 1 uses config 1, start time is 237, finish time = 261
# Task 1 uses config 1, start time is 238, finish time = 262
# Task 1 uses config 1, start time is 239, finish time = 263
# Task 1 uses config 1, start time is 240, finish time = 264
# Task 1 uses config 1, start time is 241, finish time = 265
# Task 1 uses config 1, start time is 242, finish time = 266
# Task 1 uses config 1, start time is 243, finish time = 267
# Task 1 uses config 1, start time is 244, finish time = 268
# Task 1 uses config 1, start time is 245, finish time = 269
# Task 1 uses config 1, start time is 246, finish time = 270
# Task 1 uses config 1, start time is 247, finish time = 271
# Task 1 uses config 1, start time is 248, finish time = 272
# Task 1 uses config 1, start time is 249, finish time = 273
# Task 1 uses config 1, start time is 250, finish time = 274
# Task 1 uses config 1, start time is 251, finish time = 275
# Task 1 uses config 1, start time is 252, finish time = 276
# Task 1 uses config 1, start time is 253, finish time = 277
# Task 1 uses config 1, start time is 254, finish time = 278
# Task 1 uses config 1, start time is 255, finish time = 279
# Task 1 uses config 1, start time is 256, finish time = 280
# Task 1 uses config 1, start time is 257, finish time = 281
# Task 1 uses config 1, start time is 258, finish time = 282
# Task 1 uses config 1, start time is 259, finish time = 283
# Task 1 uses config 1, start time is 260, finish time = 284
# Task 1 uses config 1, start time is 261, finish time = 285
# Task 1 uses config 1, start time is 262, finish time = 286
# Task 1 uses config 1, start time is 263, finish time = 287
# Task 1 uses config 1, start time is 264, finish time = 288
# Task 1 uses config 1, start time is 265, finish time = 289
# Task 1 uses config 1, start time is 266, finish time = 290
# Task 1 uses config 1, start time is 267, finish time = 291
# Task 1 uses config 1, start time is 268, finish time = 292
# Task 1 uses config 1, start time is 269, finish time = 293
# Task 1 uses config 1, start time is 270, finish time = 294
# Task 1 uses config 1, start time is 271, finish time = 295
# Task 1 uses config 1, start time is 272, finish time = 296
# Task 1 uses config 1, start time is 273, finish time = 297
# Task 1 uses config 1, start time is 274, finish time = 298
# Task 1 uses config 1, start time is 275, finish time = 299
# Task 1 uses config 1, start time is 276, finish time = 300
# Task 1 uses config 1, start time is 277, finish time = 301
# Task 1 uses config 1, start time is 278, finish time = 302
# Task 1 uses config 1, start time is 279, finish time = 303
# Task 1 uses config 1, start time is 280, finish time = 304
# Task 1 uses config 1, start time is 281, finish time = 305
# Task 1 uses config 1, start time is 282, finish time = 306
# Task 1 uses config 1, start time is 283, finish time = 307
# Task 1 uses config 1, start time is 284, finish time = 308
# Task 1 uses config 1, start time is 285, finish time = 309
# Task 1 uses config 1, start time is 286, finish time = 310
# Task 1 uses config 1, start time is 287, finish time = 311
# Task 1 uses config 1, start time is 288, finish time = 312
# Task 1 uses config 1, start time is 289, finish time = 313
# Task 1 uses config 1, start time is 290, finish time = 314
# Task 1 uses config 1, start time is 291, finish time = 315
# Task 1 uses config 1, start time is 292, finish time = 316
# Task 1 uses config 1, start time is 293, finish time = 317
# Task 1 uses config 1, start time is 294, finish time = 318
# Task 1 uses config 1, start time is 295, finish time = 319
# Task 1 uses config 1, start time is 296, finish time = 320
# Task 1 uses config 1, start time is 297, finish time = 321
# Task 1 uses config 1, start time is 298, finish time = 322
# Task 1 uses config 1, start time is 299, finish time = 323
# Task 1 uses config 1, start time is 300, finish time = 324
# Task 1 uses config 1, start time is 301, finish time = 325
# Task 1 uses config 1, start time is 302, finish time = 326
# Task 1 uses config 1, start time is 303, finish time = 327
# Task 1 uses config 1, start time is 304, finish time = 328
# Task 1 uses config 1, start time is 305, finish time = 329
# Task 1 uses config 1, start time is 306, finish time = 330
# Task 1 uses config 1, start time is 307, finish time = 331
# Task 1 uses config 1, start time is 308, finish time = 332
# Task 1 uses config 1, start time is 309, finish time = 333
# Task 1 uses config 1, start time is 310, finish time = 334
# Task 1 uses config 1, start time is 311, finish time = 335
# Task 1 uses config 1, start time is 312, finish time = 336
# Task 1 uses config 1, start time is 313, finish time = 337
# Task 1 uses config 1, start time is 314, finish time = 338
# Task 1 uses config 1, start time is 315, finish time = 339
# Task 1 uses config 1, start time is 316, finish time = 340
# Task 1 uses config 1, start time is 317, finish time = 341
# Task 1 uses config 1, start time is 318, finish time = 342
# Task 1 uses config 1, start time is 319, finish time = 343
# Task 1 uses config 1, start time is 320, finish time = 344
# Task 1 uses config 1, start time is 321, finish time = 345
# Task 1 uses config 1, start time is 322, finish time = 346
# Task 1 uses config 1, start time is 323, finish time = 347
# Task 1 uses config 1, start time is 324, finish time = 348
# Task 1 uses config 1, start time is 325, finish time = 349
# Task 1 uses config 1, start time is 326, finish time = 350
# Task 1 uses config 1, start time is 327, finish time = 351
# Task 1 uses config 1, start time is 328, finish time = 352
# Task 1 uses config 1, start time is 329, finish time = 353
# Task 1 uses config 1, start time is 330, finish time = 354
# Task 1 uses config 1, start time is 331, finish time = 355
# Task 1 uses config 1, start time is 332, finish time = 356
# Task 1 uses config 1, start time is 333, finish time = 357
# Task 1 uses config 1, start time is 334, finish time = 358
# Task 1 uses config 1, start time is 335, finish time = 359
# Task 1 uses config 1, start time is 336, finish time = 360
# Task 1 uses config 1, start time is 337, finish time = 361
# Task 1 uses config 1, start time is 338, finish time = 362
# Task 1 uses config 1, start time is 339, finish time = 363
# Task 1 uses config 1, start time is 340, finish time = 364
# Task 1 uses config 1, start time is 341, finish time = 365
# Task 1 uses config 1, start time is 342, finish time = 366
# Task 1 uses config 1, start time is 343, finish time = 367
# Task 1 uses config 1, start time is 344, finish time = 368
# Task 1 uses config 1, start time is 345, finish time = 369
# Task 1 uses config 1, start time is 346, finish time = 370
# Task 1 uses config 1, start time is 347, finish time = 371
# Task 1 uses config 1, start time is 348, finish time = 372
# Task 1 uses config 1, start time is 349, finish time = 373
# Task 1 uses config 1, start time is 350, finish time = 374
# Task 1 uses config 1, start time is 351, finish time = 375
# Task 1 uses config 1, start time is 352, finish time = 376
# Task 1 uses config 1, start time is 353, finish time = 377
# Task 1 uses config 1, start time is 354, finish time = 378
# Task 1 uses config 1, start time is 355, finish time = 379
# Task 1 uses config 1, start time is 356, finish time = 380
# Task 1 uses config 1, start time is 357, finish time = 381
# Task 1 uses config 1, start time is 358, finish time = 382
# Task 1 uses config 1, start time is 359, finish time = 383
# Task 1 uses config 1, start time is 360, finish time = 384
# Task 1 uses config 1, start time is 361, finish time = 385
# Task 1 uses config 1, start time is 362, finish time = 386
# Task 1 uses config 1, start time is 363, finish time = 387
# Task 1 uses config 1, start time is 364, finish time = 388
# Task 1 uses config 1, start time is 365, finish time = 389
# Task 1 uses config 1, start time is 366, finish time = 390
# Task 1 uses config 1, start time is 367, finish time = 391
# Task 1 uses config 1, start time is 368, finish time = 392
# Task 1 uses config 1, start time is 369, finish time = 393
# Task 1 uses config 1, start time is 370, finish time = 394
# Task 1 uses config 1, start time is 371, finish time = 395
# Task 1 uses config 1, start time is 372, finish time = 396
# Task 1 uses config 1, start time is 373, finish time = 397
# Task 1 uses config 1, start time is 374, finish time = 398
# Task 1 uses config 1, start time is 375, finish time = 399
# Task 1 uses config 1, start time is 376, finish time = 400
# Task 1 uses config 1, start time is 377, finish time = 401
# Task 1 uses config 1, start time is 378, finish time = 402
# Task 1 uses config 1, start time is 379, finish time = 403
# Task 1 uses config 1, start time is 380, finish time = 404
# Task 1 uses config 1, start time is 381, finish time = 405
# Task 1 uses config 1, start time is 382, finish time = 406
# Task 1 uses config 1, start time is 383, finish time = 407
# Task 1 uses config 1, start time is 384, finish time = 408
# Task 1 uses config 1, start time is 385, finish time = 409
# Task 1 uses config 1, start time is 386, finish time = 410
# Task 1 uses config 1, start time is 387, finish time = 411
# Task 1 uses config 1, start time is 388, finish time = 412
# Task 1 uses config 1, start time is 389, finish time = 413
# Task 1 uses config 1, start time is 390, finish time = 414
# Task 1 uses config 1, start time is 391, finish time = 415
# Task 1 uses config 1, start time is 392, finish time = 416
# Task 1 uses config 1, start time is 393, finish time = 417
# Task 1 uses config 1, start time is 394, finish time = 418
# Task 1 uses config 1, start time is 395, finish time = 419
# Task 1 uses config 1, start time is 396, finish time = 420
# Task 1 uses config 1, start time is 397, finish time = 421
# Task 1 uses config 1, start time is 398, finish time = 422
# Task 1 uses config 1, start time is 399, finish time = 423
# Task 1 uses config 1, start time is 400, finish time = 424
# Task 1 uses config 1, start time is 401, finish time = 425
# Task 1 uses config 1, start time is 402, finish time = 426
# Task 1 uses config 1, start time is 403, finish time = 427
# Task 1 uses config 1, start time is 404, finish time = 428
# Task 1 uses config 1, start time is 405, finish time = 429
# Task 1 uses config 1, start time is 406, finish time = 430
# Task 1 uses config 1, start time is 407, finish time = 431
# Task 1 uses config 1, start time is 408, finish time = 432
# Task 1 uses config 1, start time is 409, finish time = 433
# Task 1 uses config 1, start time is 410, finish time = 434
# Task 1 uses config 1, start time is 411, finish time = 435
# Task 1 uses config 1, start time is 412, finish time = 436
# Task 1 uses config 1, start time is 413, finish time = 437
# Task 1 uses config 1, start time is 414, finish time = 438
# Task 1 uses config 1, start time is 415, finish time = 439
# Task 1 uses config 1, start time is 416, finish time = 440
# Task 1 uses config 1, start time is 417, finish time = 441
# Task 1 uses config 1, start time is 418, finish time = 442
# Task 1 uses config 1, start time is 419, finish time = 443
# Task 1 uses config 1, start time is 420, finish time = 444
# Task 1 uses config 1, start time is 421, finish time = 445
# Task 1 uses config 1, start time is 422, finish time = 446
# Task 1 uses config 1, start time is 423, finish time = 447
# Task 1 uses config 1, start time is 424, finish time = 448
# Task 1 uses config 1, start time is 425, finish time = 449
# Task 1 uses config 1, start time is 426, finish time = 450
# Task 1 uses config 1, start time is 427, finish time = 451
# Task 1 uses config 2, start time is 0, finish time = 14
# Task 1 uses config 2, start time is 1, finish time = 15
# Task 1 uses config 2, start time is 2, finish time = 16
# Task 1 uses config 2, start time is 3, finish time = 17
# Task 1 uses config 2, start time is 4, finish time = 18
# Task 1 uses config 2, start time is 5, finish time = 19
# Task 1 uses config 2, start time is 6, finish time = 20
# Task 1 uses config 2, start time is 7, finish time = 21
# Task 1 uses config 2, start time is 8, finish time = 22
# Task 1 uses config 2, start time is 9, finish time = 23
# Task 1 uses config 2, start time is 10, finish time = 24
# Task 1 uses config 2, start time is 11, finish time = 25
# Task 1 uses config 2, start time is 12, finish time = 26
# Task 1 uses config 2, start time is 13, finish time = 27
# Task 1 uses config 2, start time is 14, finish time = 28
# Task 1 uses config 2, start time is 15, finish time = 29
# Task 1 uses config 2, start time is 16, finish time = 30
# Task 1 uses config 2, start time is 17, finish time = 31
# Task 1 uses config 2, start time is 18, finish time = 32
# Task 1 uses config 2, start time is 19, finish time = 33
# Task 1 uses config 2, start time is 20, finish time = 34
# Task 1 uses config 2, start time is 21, finish time = 35
# Task 1 uses config 2, start time is 22, finish time = 36
# Task 1 uses config 2, start time is 23, finish time = 37
# Task 1 uses config 2, start time is 24, finish time = 38
# Task 1 uses config 2, start time is 25, finish time = 39
# Task 1 uses config 2, start time is 26, finish time = 40
# Task 1 uses config 2, start time is 27, finish time = 41
# Task 1 uses config 2, start time is 28, finish time = 42
# Task 1 uses config 2, start time is 29, finish time = 43
# Task 1 uses config 2, start time is 30, finish time = 44
# Task 1 uses config 2, start time is 31, finish time = 45
# Task 1 uses config 2, start time is 32, finish time = 46
# Task 1 uses config 2, start time is 33, finish time = 47
# Task 1 uses config 2, start time is 34, finish time = 48
# Task 1 uses config 2, start time is 35, finish time = 49
# Task 1 uses config 2, start time is 36, finish time = 50
# Task 1 uses config 2, start time is 37, finish time = 51
# Task 1 uses config 2, start time is 38, finish time = 52
# Task 1 uses config 2, start time is 39, finish time = 53
# Task 1 uses config 2, start time is 40, finish time = 54
# Task 1 uses config 2, start time is 41, finish time = 55
# Task 1 uses config 2, start time is 42, finish time = 56
# Task 1 uses config 2, start time is 43, finish time = 57
# Task 1 uses config 2, start time is 44, finish time = 58
# Task 1 uses config 2, start time is 45, finish time = 59
# Task 1 uses config 2, start time is 46, finish time = 60
# Task 1 uses config 2, start time is 47, finish time = 61
# Task 1 uses config 2, start time is 48, finish time = 62
# Task 1 uses config 2, start time is 49, finish time = 63
# Task 1 uses config 2, start time is 50, finish time = 64
# Task 1 uses config 2, start time is 51, finish time = 65
# Task 1 uses config 2, start time is 52, finish time = 66
# Task 1 uses config 2, start time is 53, finish time = 67
# Task 1 uses config 2, start time is 54, finish time = 68
# Task 1 uses config 2, start time is 55, finish time = 69
# Task 1 uses config 2, start time is 56, finish time = 70
# Task 1 uses config 2, start time is 57, finish time = 71
# Task 1 uses config 2, start time is 58, finish time = 72
# Task 1 uses config 2, start time is 59, finish time = 73
# Task 1 uses config 2, start time is 60, finish time = 74
# Task 1 uses config 2, start time is 61, finish time = 75
# Task 1 uses config 2, start time is 62, finish time = 76
# Task 1 uses config 2, start time is 63, finish time = 77
# Task 1 uses config 2, start time is 64, finish time = 78
# Task 1 uses config 2, start time is 65, finish time = 79
# Task 1 uses config 2, start time is 66, finish time = 80
# Task 1 uses config 2, start time is 67, finish time = 81
# Task 1 uses config 2, start time is 68, finish time = 82
# Task 1 uses config 2, start time is 69, finish time = 83
# Task 1 uses config 2, start time is 70, finish time = 84
# Task 1 uses config 2, start time is 71, finish time = 85
# Task 1 uses config 2, start time is 72, finish time = 86
# Task 1 uses config 2, start time is 73, finish time = 87
# Task 1 uses config 2, start time is 74, finish time = 88
# Task 1 uses config 2, start time is 75, finish time = 89
# Task 1 uses config 2, start time is 76, finish time = 90
# Task 1 uses config 2, start time is 77, finish time = 91
# Task 1 uses config 2, start time is 78, finish time = 92
# Task 1 uses config 2, start time is 79, finish time = 93
# Task 1 uses config 2, start time is 80, finish time = 94
# Task 1 uses config 2, start time is 81, finish time = 95
# Task 1 uses config 2, start time is 82, finish time = 96
# Task 1 uses config 2, start time is 83, finish time = 97
# Task 1 uses config 2, start time is 84, finish time = 98
# Task 1 uses config 2, start time is 85, finish time = 99
# Task 1 uses config 2, start time is 86, finish time = 100
# Task 1 uses config 2, start time is 87, finish time = 101
# Task 1 uses config 2, start time is 88, finish time = 102
# Task 1 uses config 2, start time is 89, finish time = 103
# Task 1 uses config 2, start time is 90, finish time = 104
# Task 1 uses config 2, start time is 91, finish time = 105
# Task 1 uses config 2, start time is 92, finish time = 106
# Task 1 uses config 2, start time is 93, finish time = 107
# Task 1 uses config 2, start time is 94, finish time = 108
# Task 1 uses config 2, start time is 95, finish time = 109
# Task 1 uses config 2, start time is 96, finish time = 110
# Task 1 uses config 2, start time is 97, finish time = 111
# Task 1 uses config 2, start time is 98, finish time = 112
# Task 1 uses config 2, start time is 99, finish time = 113
# Task 1 uses config 2, start time is 100, finish time = 114
# Task 1 uses config 2, start time is 101, finish time = 115
# Task 1 uses config 2, start time is 102, finish time = 116
# Task 1 uses config 2, start time is 103, finish time = 117
# Task 1 uses config 2, start time is 104, finish time = 118
# Task 1 uses config 2, start time is 105, finish time = 119
# Task 1 uses config 2, start time is 106, finish time = 120
# Task 1 uses config 2, start time is 107, finish time = 121
# Task 1 uses config 2, start time is 108, finish time = 122
# Task 1 uses config 2, start time is 109, finish time = 123
# Task 1 uses config 2, start time is 110, finish time = 124
# Task 1 uses config 2, start time is 111, finish time = 125
# Task 1 uses config 2, start time is 112, finish time = 126
# Task 1 uses config 2, start time is 113, finish time = 127
# Task 1 uses config 2, start time is 114, finish time = 128
# Task 1 uses config 2, start time is 115, finish time = 129
# Task 1 uses config 2, start time is 116, finish time = 130
# Task 1 uses config 2, start time is 117, finish time = 131
# Task 1 uses config 2, start time is 118, finish time = 132
# Task 1 uses config 2, start time is 119, finish time = 133
# Task 1 uses config 2, start time is 120, finish time = 134
# Task 1 uses config 2, start time is 121, finish time = 135
# Task 1 uses config 2, start time is 122, finish time = 136
# Task 1 uses config 2, start time is 123, finish time = 137
# Task 1 uses config 2, start time is 124, finish time = 138
# Task 1 uses config 2, start time is 125, finish time = 139
# Task 1 uses config 2, start time is 126, finish time = 140
# Task 1 uses config 2, start time is 127, finish time = 141
# Task 1 uses config 2, start time is 128, finish time = 142
# Task 1 uses config 2, start time is 129, finish time = 143
# Task 1 uses config 2, start time is 130, finish time = 144
# Task 1 uses config 2, start time is 131, finish time = 145
# Task 1 uses config 2, start time is 132, finish time = 146
# Task 1 uses config 2, start time is 133, finish time = 147
# Task 1 uses config 2, start time is 134, finish time = 148
# Task 1 uses config 2, start time is 135, finish time = 149
# Task 1 uses config 2, start time is 136, finish time = 150
# Task 1 uses config 2, start time is 137, finish time = 151
# Task 1 uses config 2, start time is 138, finish time = 152
# Task 1 uses config 2, start time is 139, finish time = 153
# Task 1 uses config 2, start time is 140, finish time = 154
# Task 1 uses config 2, start time is 141, finish time = 155
# Task 1 uses config 2, start time is 142, finish time = 156
# Task 1 uses config 2, start time is 143, finish time = 157
# Task 1 uses config 2, start time is 144, finish time = 158
# Task 1 uses config 2, start time is 145, finish time = 159
# Task 1 uses config 2, start time is 146, finish time = 160
# Task 1 uses config 2, start time is 147, finish time = 161
# Task 1 uses config 2, start time is 148, finish time = 162
# Task 1 uses config 2, start time is 149, finish time = 163
# Task 1 uses config 2, start time is 150, finish time = 164
# Task 1 uses config 2, start time is 151, finish time = 165
# Task 1 uses config 2, start time is 152, finish time = 166
# Task 1 uses config 2, start time is 153, finish time = 167
# Task 1 uses config 2, start time is 154, finish time = 168
# Task 1 uses config 2, start time is 155, finish time = 169
# Task 1 uses config 2, start time is 156, finish time = 170
# Task 1 uses config 2, start time is 157, finish time = 171
# Task 1 uses config 2, start time is 158, finish time = 172
# Task 1 uses config 2, start time is 159, finish time = 173
# Task 1 uses config 2, start time is 160, finish time = 174
# Task 1 uses config 2, start time is 161, finish time = 175
# Task 1 uses config 2, start time is 162, finish time = 176
# Task 1 uses config 2, start time is 163, finish time = 177
# Task 1 uses config 2, start time is 164, finish time = 178
# Task 1 uses config 2, start time is 165, finish time = 179
# Task 1 uses config 2, start time is 166, finish time = 180
# Task 1 uses config 2, start time is 167, finish time = 181
# Task 1 uses config 2, start time is 168, finish time = 182
# Task 1 uses config 2, start time is 169, finish time = 183
# Task 1 uses config 2, start time is 170, finish time = 184
# Task 1 uses config 2, start time is 171, finish time = 185
# Task 1 uses config 2, start time is 172, finish time = 186
# Task 1 uses config 2, start time is 173, finish time = 187
# Task 1 uses config 2, start time is 174, finish time = 188
# Task 1 uses config 2, start time is 175, finish time = 189
# Task 1 uses config 2, start time is 176, finish time = 190
# Task 1 uses config 2, start time is 177, finish time = 191
# Task 1 uses config 2, start time is 178, finish time = 192
# Task 1 uses config 2, start time is 179, finish time = 193
# Task 1 uses config 2, start time is 180, finish time = 194
# Task 1 uses config 2, start time is 181, finish time = 195
# Task 1 uses config 2, start time is 182, finish time = 196
# Task 1 uses config 2, start time is 183, finish time = 197
# Task 1 uses config 2, start time is 184, finish time = 198
# Task 1 uses config 2, start time is 185, finish time = 199
# Task 1 uses config 2, start time is 186, finish time = 200
# Task 1 uses config 2, start time is 187, finish time = 201
# Task 1 uses config 2, start time is 188, finish time = 202
# Task 1 uses config 2, start time is 189, finish time = 203
# Task 1 uses config 2, start time is 190, finish time = 204
# Task 1 uses config 2, start time is 191, finish time = 205
# Task 1 uses config 2, start time is 192, finish time = 206
# Task 1 uses config 2, start time is 193, finish time = 207
# Task 1 uses config 2, start time is 194, finish time = 208
# Task 1 uses config 2, start time is 195, finish time = 209
# Task 1 uses config 2, start time is 196, finish time = 210
# Task 1 uses config 2, start time is 197, finish time = 211
# Task 1 uses config 2, start time is 198, finish time = 212
# Task 1 uses config 2, start time is 199, finish time = 213
# Task 1 uses config 2, start time is 200, finish time = 214
# Task 1 uses config 2, start time is 201, finish time = 215
# Task 1 uses config 2, start time is 202, finish time = 216
# Task 1 uses config 2, start time is 203, finish time = 217
# Task 1 uses config 2, start time is 204, finish time = 218
# Task 1 uses config 2, start time is 205, finish time = 219
# Task 1 uses config 2, start time is 206, finish time = 220
# Task 1 uses config 2, start time is 207, finish time = 221
# Task 1 uses config 2, start time is 208, finish time = 222
# Task 1 uses config 2, start time is 209, finish time = 223
# Task 1 uses config 2, start time is 210, finish time = 224
# Task 1 uses config 2, start time is 211, finish time = 225
# Task 1 uses config 2, start time is 212, finish time = 226
# Task 1 uses config 2, start time is 213, finish time = 227
# Task 1 uses config 2, start time is 214, finish time = 228
# Task 1 uses config 2, start time is 215, finish time = 229
# Task 1 uses config 2, start time is 216, finish time = 230
# Task 1 uses config 2, start time is 217, finish time = 231
# Task 1 uses config 2, start time is 218, finish time = 232
# Task 1 uses config 2, start time is 219, finish time = 233
# Task 1 uses config 2, start time is 220, finish time = 234
# Task 1 uses config 2, start time is 221, finish time = 235
# Task 1 uses config 2, start time is 222, finish time = 236
# Task 1 uses config 2, start time is 223, finish time = 237
# Task 1 uses config 2, start time is 224, finish time = 238
# Task 1 uses config 2, start time is 225, finish time = 239
# Task 1 uses config 2, start time is 226, finish time = 240
# Task 1 uses config 2, start time is 227, finish time = 241
# Task 1 uses config 2, start time is 228, finish time = 242
# Task 1 uses config 2, start time is 229, finish time = 243
# Task 1 uses config 2, start time is 230, finish time = 244
# Task 1 uses config 2, start time is 231, finish time = 245
# Task 1 uses config 2, start time is 232, finish time = 246
# Task 1 uses config 2, start time is 233, finish time = 247
# Task 1 uses config 2, start time is 234, finish time = 248
# Task 1 uses config 2, start time is 235, finish time = 249
# Task 1 uses config 2, start time is 236, finish time = 250
# Task 1 uses config 2, start time is 237, finish time = 251
# Task 1 uses config 2, start time is 238, finish time = 252
# Task 1 uses config 2, start time is 239, finish time = 253
# Task 1 uses config 2, start time is 240, finish time = 254
# Task 1 uses config 2, start time is 241, finish time = 255
# Task 1 uses config 2, start time is 242, finish time = 256
# Task 1 uses config 2, start time is 243, finish time = 257
# Task 1 uses config 2, start time is 244, finish time = 258
# Task 1 uses config 2, start time is 245, finish time = 259
# Task 1 uses config 2, start time is 246, finish time = 260
# Task 1 uses config 2, start time is 247, finish time = 261
# Task 1 uses config 2, start time is 248, finish time = 262
# Task 1 uses config 2, start time is 249, finish time = 263
# Task 1 uses config 2, start time is 250, finish time = 264
# Task 1 uses config 2, start time is 251, finish time = 265
# Task 1 uses config 2, start time is 252, finish time = 266
# Task 1 uses config 2, start time is 253, finish time = 267
# Task 1 uses config 2, start time is 254, finish time = 268
# Task 1 uses config 2, start time is 255, finish time = 269
# Task 1 uses config 2, start time is 256, finish time = 270
# Task 1 uses config 2, start time is 257, finish time = 271
# Task 1 uses config 2, start time is 258, finish time = 272
# Task 1 uses config 2, start time is 259, finish time = 273
# Task 1 uses config 2, start time is 260, finish time = 274
# Task 1 uses config 2, start time is 261, finish time = 275
# Task 1 uses config 2, start time is 262, finish time = 276
# Task 1 uses config 2, start time is 263, finish time = 277
# Task 1 uses config 2, start time is 264, finish time = 278
# Task 1 uses config 2, start time is 265, finish time = 279
# Task 1 uses config 2, start time is 266, finish time = 280
# Task 1 uses config 2, start time is 267, finish time = 281
# Task 1 uses config 2, start time is 268, finish time = 282
# Task 1 uses config 2, start time is 269, finish time = 283
# Task 1 uses config 2, start time is 270, finish time = 284
# Task 1 uses config 2, start time is 271, finish time = 285
# Task 1 uses config 2, start time is 272, finish time = 286
# Task 1 uses config 2, start time is 273, finish time = 287
# Task 1 uses config 2, start time is 274, finish time = 288
# Task 1 uses config 2, start time is 275, finish time = 289
# Task 1 uses config 2, start time is 276, finish time = 290
# Task 1 uses config 2, start time is 277, finish time = 291
# Task 1 uses config 2, start time is 278, finish time = 292
# Task 1 uses config 2, start time is 279, finish time = 293
# Task 1 uses config 2, start time is 280, finish time = 294
# Task 1 uses config 2, start time is 281, finish time = 295
# Task 1 uses config 2, start time is 282, finish time = 296
# Task 1 uses config 2, start time is 283, finish time = 297
# Task 1 uses config 2, start time is 284, finish time = 298
# Task 1 uses config 2, start time is 285, finish time = 299
# Task 1 uses config 2, start time is 286, finish time = 300
# Task 1 uses config 2, start time is 287, finish time = 301
# Task 1 uses config 2, start time is 288, finish time = 302
# Task 1 uses config 2, start time is 289, finish time = 303
# Task 1 uses config 2, start time is 290, finish time = 304
# Task 1 uses config 2, start time is 291, finish time = 305
# Task 1 uses config 2, start time is 292, finish time = 306
# Task 1 uses config 2, start time is 293, finish time = 307
# Task 1 uses config 2, start time is 294, finish time = 308
# Task 1 uses config 2, start time is 295, finish time = 309
# Task 1 uses config 2, start time is 296, finish time = 310
# Task 1 uses config 2, start time is 297, finish time = 311
# Task 1 uses config 2, start time is 298, finish time = 312
# Task 1 uses config 2, start time is 299, finish time = 313
# Task 1 uses config 2, start time is 300, finish time = 314
# Task 1 uses config 2, start time is 301, finish time = 315
# Task 1 uses config 2, start time is 302, finish time = 316
# Task 1 uses config 2, start time is 303, finish time = 317
# Task 1 uses config 2, start time is 304, finish time = 318
# Task 1 uses config 2, start time is 305, finish time = 319
# Task 1 uses config 2, start time is 306, finish time = 320
# Task 1 uses config 2, start time is 307, finish time = 321
# Task 1 uses config 2, start time is 308, finish time = 322
# Task 1 uses config 2, start time is 309, finish time = 323
# Task 1 uses config 2, start time is 310, finish time = 324
# Task 1 uses config 2, start time is 311, finish time = 325
# Task 1 uses config 2, start time is 312, finish time = 326
# Task 1 uses config 2, start time is 313, finish time = 327
# Task 1 uses config 2, start time is 314, finish time = 328
# Task 1 uses config 2, start time is 315, finish time = 329
# Task 1 uses config 2, start time is 316, finish time = 330
# Task 1 uses config 2, start time is 317, finish time = 331
# Task 1 uses config 2, start time is 318, finish time = 332
# Task 1 uses config 2, start time is 319, finish time = 333
# Task 1 uses config 2, start time is 320, finish time = 334
# Task 1 uses config 2, start time is 321, finish time = 335
# Task 1 uses config 2, start time is 322, finish time = 336
# Task 1 uses config 2, start time is 323, finish time = 337
# Task 1 uses config 2, start time is 324, finish time = 338
# Task 1 uses config 2, start time is 325, finish time = 339
# Task 1 uses config 2, start time is 326, finish time = 340
# Task 1 uses config 2, start time is 327, finish time = 341
# Task 1 uses config 2, start time is 328, finish time = 342
# Task 1 uses config 2, start time is 329, finish time = 343
# Task 1 uses config 2, start time is 330, finish time = 344
# Task 1 uses config 2, start time is 331, finish time = 345
# Task 1 uses config 2, start time is 332, finish time = 346
# Task 1 uses config 2, start time is 333, finish time = 347
# Task 1 uses config 2, start time is 334, finish time = 348
# Task 1 uses config 2, start time is 335, finish time = 349
# Task 1 uses config 2, start time is 336, finish time = 350
# Task 1 uses config 2, start time is 337, finish time = 351
# Task 1 uses config 2, start time is 338, finish time = 352
# Task 1 uses config 2, start time is 339, finish time = 353
# Task 1 uses config 2, start time is 340, finish time = 354
# Task 1 uses config 2, start time is 341, finish time = 355
# Task 1 uses config 2, start time is 342, finish time = 356
# Task 1 uses config 2, start time is 343, finish time = 357
# Task 1 uses config 2, start time is 344, finish time = 358
# Task 1 uses config 2, start time is 345, finish time = 359
# Task 1 uses config 2, start time is 346, finish time = 360
# Task 1 uses config 2, start time is 347, finish time = 361
# Task 1 uses config 2, start time is 348, finish time = 362
# Task 1 uses config 2, start time is 349, finish time = 363
# Task 1 uses config 2, start time is 350, finish time = 364
# Task 1 uses config 2, start time is 351, finish time = 365
# Task 1 uses config 2, start time is 352, finish time = 366
# Task 1 uses config 2, start time is 353, finish time = 367
# Task 1 uses config 2, start time is 354, finish time = 368
# Task 1 uses config 2, start time is 355, finish time = 369
# Task 1 uses config 2, start time is 356, finish time = 370
# Task 1 uses config 2, start time is 357, finish time = 371
# Task 1 uses config 2, start time is 358, finish time = 372
# Task 1 uses config 2, start time is 359, finish time = 373
# Task 1 uses config 2, start time is 360, finish time = 374
# Task 1 uses config 2, start time is 361, finish time = 375
# Task 1 uses config 2, start time is 362, finish time = 376
# Task 1 uses config 2, start time is 363, finish time = 377
# Task 1 uses config 2, start time is 364, finish time = 378
# Task 1 uses config 2, start time is 365, finish time = 379
# Task 1 uses config 2, start time is 366, finish time = 380
# Task 1 uses config 2, start time is 367, finish time = 381
# Task 1 uses config 2, start time is 368, finish time = 382
# Task 1 uses config 2, start time is 369, finish time = 383
# Task 1 uses config 2, start time is 370, finish time = 384
# Task 1 uses config 2, start time is 371, finish time = 385
# Task 1 uses config 2, start time is 372, finish time = 386
# Task 1 uses config 2, start time is 373, finish time = 387
# Task 1 uses config 2, start time is 374, finish time = 388
# Task 1 uses config 2, start time is 375, finish time = 389
# Task 1 uses config 2, start time is 376, finish time = 390
# Task 1 uses config 2, start time is 377, finish time = 391
# Task 1 uses config 2, start time is 378, finish time = 392
# Task 1 uses config 2, start time is 379, finish time = 393
# Task 1 uses config 2, start time is 380, finish time = 394
# Task 1 uses config 2, start time is 381, finish time = 395
# Task 1 uses config 2, start time is 382, finish time = 396
# Task 1 uses config 2, start time is 383, finish time = 397
# Task 1 uses config 2, start time is 384, finish time = 398
# Task 1 uses config 2, start time is 385, finish time = 399
# Task 1 uses config 2, start time is 386, finish time = 400
# Task 1 uses config 2, start time is 387, finish time = 401
# Task 1 uses config 2, start time is 388, finish time = 402
# Task 1 uses config 2, start time is 389, finish time = 403
# Task 1 uses config 2, start time is 390, finish time = 404
# ...
# Task 10 uses config 2, start time is 380, finish time = 393
# Task 10 uses config 2, start time is 381, finish time = 394
# Task 10 uses config 2, start time is 382, finish time = 395
# Task 10 uses config 2, start time is 383, finish time = 396
# Task 10 uses config 2, start time is 384, finish time = 397
# Task 10 uses config 2, start time is 385, finish time = 398
# Task 10 uses config 2, start time is 386, finish time = 399
# Task 10 uses config 2, start time is 387, finish time = 400
# Task 10 uses config 2, start time is 388, finish time = 401
# Task 10 uses config 2, start time is 389, finish time = 402
# Task 10 uses config 2, start time is 390, finish time = 403
# Task 10 uses config 2, start time is 391, finish time = 404
# Task 10 uses config 2, start time is 392, finish time = 405
# Task 10 uses config 2, start time is 393, finish time = 406
# Task 10 uses config 2, start time is 394, finish time = 407
# Task 10 uses config 2, start time is 395, finish time = 408
# Task 10 uses config 2, start time is 396, finish time = 409
# Task 10 uses config 2, start time is 397, finish time = 410
# Task 10 uses config 2, start time is 398, finish time = 411
# Task 10 uses config 2, start time is 399, finish time = 412
# Task 10 uses config 2, start time is 400, finish time = 413
# Task 10 uses config 2, start time is 401, finish time = 414
# Task 10 uses config 2, start time is 402, finish time = 415
# Task 10 uses config 2, start time is 403, finish time = 416
# Task 10 uses config 2, start time is 404, finish time = 417
# Task 10 uses config 2, start time is 405, finish time = 418
# Task 10 uses config 2, start time is 406, finish time = 419
# Task 10 uses config 2, start time is 407, finish time = 420
# Task 10 uses config 2, start time is 408, finish time = 421
# Task 10 uses config 2, start time is 409, finish time = 422
# Task 10 uses config 2, start time is 410, finish time = 423
# Task 10 uses config 2, start time is 411, finish time = 424
# Task 10 uses config 2, start time is 412, finish time = 425
# Task 10 uses config 2, start time is 413, finish time = 426
# Task 10 uses config 2, start time is 414, finish time = 427
# Task 10 uses config 2, start time is 415, finish time = 428
# Task 10 uses config 2, start time is 416, finish time = 429
# Task 10 uses config 2, start time is 417, finish time = 430
# Task 10 uses config 2, start time is 418, finish time = 431
# Task 10 uses config 2, start time is 419, finish time = 432
# Task 10 uses config 2, start time is 420, finish time = 433
# Task 10 uses config 2, start time is 421, finish time = 434
# Task 10 uses config 2, start time is 422, finish time = 435
# Task 10 uses config 2, start time is 423, finish time = 436
# Task 10 uses config 2, start time is 424, finish time = 437
# Task 10 uses config 2, start time is 425, finish time = 438
# Task 10 uses config 2, start time is 426, finish time = 439
# Task 10 uses config 2, start time is 427, finish time = 440
# Task 10 uses config 2, start time is 428, finish time = 441
# Task 10 uses config 2, start time is 429, finish time = 442
# Task 10 uses config 2, start time is 430, finish time = 443
# Task 10 uses config 2, start time is 431, finish time = 444
# Task 10 uses config 2, start time is 432, finish time = 445
# Task 10 uses config 2, start time is 433, finish time = 446
# Task 10 uses config 2, start time is 434, finish time = 447
# Task 10 uses config 2, start time is 435, finish time = 448
# Task 10 uses config 2, start time is 436, finish time = 449
# Task 10 uses config 2, start time is 437, finish time = 450
# Task 10 uses config 2, start time is 438, finish time = 451
# Task 11 uses config 1, start time is 0, finish time = 27
# Task 11 uses config 1, start time is 1, finish time = 28
# Task 11 uses config 1, start time is 2, finish time = 29
# Task 11 uses config 1, start time is 3, finish time = 30
# Task 11 uses config 1, start time is 4, finish time = 31
# Task 11 uses config 1, start time is 5, finish time = 32
# Task 11 uses config 1, start time is 6, finish time = 33
# Task 11 uses config 1, start time is 7, finish time = 34
# Task 11 uses config 1, start time is 8, finish time = 35
# Task 11 uses config 1, start time is 9, finish time = 36
# Task 11 uses config 1, start time is 10, finish time = 37
# Task 11 uses config 1, start time is 11, finish time = 38
# Task 11 uses config 1, start time is 12, finish time = 39
# Task 11 uses config 1, start time is 13, finish time = 40
# Task 11 uses config 1, start time is 14, finish time = 41
# Task 11 uses config 1, start time is 15, finish time = 42
# Task 11 uses config 1, start time is 16, finish time = 43
# Task 11 uses config 1, start time is 17, finish time = 44
# Task 11 uses config 1, start time is 18, finish time = 45
# Task 11 uses config 1, start time is 19, finish time = 46
# Task 11 uses config 1, start time is 20, finish time = 47
# Task 11 uses config 1, start time is 21, finish time = 48
# Task 11 uses config 1, start time is 22, finish time = 49
# Task 11 uses config 1, start time is 23, finish time = 50
# Task 11 uses config 1, start time is 24, finish time = 51
# Task 11 uses config 1, start time is 25, finish time = 52
# Task 11 uses config 1, start time is 26, finish time = 53
# Task 11 uses config 1, start time is 27, finish time = 54
# Task 11 uses config 1, start time is 28, finish time = 55
# Task 11 uses config 1, start time is 29, finish time = 56
# Task 11 uses config 1, start time is 30, finish time = 57
# Task 11 uses config 1, start time is 31, finish time = 58
# Task 11 uses config 1, start time is 32, finish time = 59
# Task 11 uses config 1, start time is 33, finish time = 60
# Task 11 uses config 1, start time is 34, finish time = 61
# Task 11 uses config 1, start time is 35, finish time = 62
# Task 11 uses config 1, start time is 36, finish time = 63
# Task 11 uses config 1, start time is 37, finish time = 64
# Task 11 uses config 1, start time is 38, finish time = 65
# Task 11 uses config 1, start time is 39, finish time = 66
# Task 11 uses config 1, start time is 40, finish time = 67
# Task 11 uses config 1, start time is 41, finish time = 68
# Task 11 uses config 1, start time is 42, finish time = 69
# Task 11 uses config 1, start time is 43, finish time = 70
# Task 11 uses config 1, start time is 44, finish time = 71
# Task 11 uses config 1, start time is 45, finish time = 72
# Task 11 uses config 1, start time is 46, finish time = 73
# Task 11 uses config 1, start time is 47, finish time = 74
# Task 11 uses config 1, start time is 48, finish time = 75
# Task 11 uses config 1, start time is 49, finish time = 76
# Task 11 uses config 1, start time is 50, finish time = 77
# Task 11 uses config 1, start time is 51, finish time = 78
# Task 11 uses config 1, start time is 52, finish time = 79
# Task 11 uses config 1, start time is 53, finish time = 80
# Task 11 uses config 1, start time is 54, finish time = 81
# Task 11 uses config 1, start time is 55, finish time = 82
# Task 11 uses config 1, start time is 56, finish time = 83
# Task 11 uses config 1, start time is 57, finish time = 84
# Task 11 uses config 1, start time is 58, finish time = 85
# Task 11 uses config 1, start time is 59, finish time = 86
# Task 11 uses config 1, start time is 60, finish time = 87
# Task 11 uses config 1, start time is 61, finish time = 88
# Task 11 uses config 1, start time is 62, finish time = 89
# Task 11 uses config 1, start time is 63, finish time = 90
# Task 11 uses config 1, start time is 64, finish time = 91
# Task 11 uses config 1, start time is 65, finish time = 92
# Task 11 uses config 1, start time is 66, finish time = 93
# Task 11 uses config 1, start time is 67, finish time = 94
# Task 11 uses config 1, start time is 68, finish time = 95
# Task 11 uses config 1, start time is 69, finish time = 96
# Task 11 uses config 1, start time is 70, finish time = 97
# Task 11 uses config 1, start time is 71, finish time = 98
# Task 11 uses config 1, start time is 72, finish time = 99
# Task 11 uses config 1, start time is 73, finish time = 100
# Task 11 uses config 1, start time is 74, finish time = 101
# Task 11 uses config 1, start time is 75, finish time = 102
# Task 11 uses config 1, start time is 76, finish time = 103
# Task 11 uses config 1, start time is 77, finish time = 104
# Task 11 uses config 1, start time is 78, finish time = 105
# Task 11 uses config 1, start time is 79, finish time = 106
# Task 11 uses config 1, start time is 80, finish time = 107
# Task 11 uses config 1, start time is 81, finish time = 108
# Task 11 uses config 1, start time is 82, finish time = 109
# Task 11 uses config 1, start time is 83, finish time = 110
# Task 11 uses config 1, start time is 84, finish time = 111
# Task 11 uses config 1, start time is 85, finish time = 112
# Task 11 uses config 1, start time is 86, finish time = 113
# Task 11 uses config 1, start time is 87, finish time = 114
# Task 11 uses config 1, start time is 88, finish time = 115
# Task 11 uses config 1, start time is 89, finish time = 116
# Task 11 uses config 1, start time is 90, finish time = 117
# Task 11 uses config 1, start time is 91, finish time = 118
# Task 11 uses config 1, start time is 92, finish time = 119
# Task 11 uses config 1, start time is 93, finish time = 120
# Task 11 uses config 1, start time is 94, finish time = 121
# Task 11 uses config 1, start time is 95, finish time = 122
# Task 11 uses config 1, start time is 96, finish time = 123
# Task 11 uses config 1, start time is 97, finish time = 124
# Task 11 uses config 1, start time is 98, finish time = 125
# Task 11 uses config 1, start time is 99, finish time = 126
# Task 11 uses config 1, start time is 100, finish time = 127
# Task 11 uses config 1, start time is 101, finish time = 128
# Task 11 uses config 1, start time is 102, finish time = 129
# Task 11 uses config 1, start time is 103, finish time = 130
# Task 11 uses config 1, start time is 104, finish time = 131
# Task 11 uses config 1, start time is 105, finish time = 132
# Task 11 uses config 1, start time is 106, finish time = 133
# Task 11 uses config 1, start time is 107, finish time = 134
# Task 11 uses config 1, start time is 108, finish time = 135
# Task 11 uses config 1, start time is 109, finish time = 136
# Task 11 uses config 1, start time is 110, finish time = 137
# Task 11 uses config 1, start time is 111, finish time = 138
# Task 11 uses config 1, start time is 112, finish time = 139
# Task 11 uses config 1, start time is 113, finish time = 140
# Task 11 uses config 1, start time is 114, finish time = 141
# Task 11 uses config 1, start time is 115, finish time = 142
# Task 11 uses config 1, start time is 116, finish time = 143
# Task 11 uses config 1, start time is 117, finish time = 144
# Task 11 uses config 1, start time is 118, finish time = 145
# Task 11 uses config 1, start time is 119, finish time = 146
# Task 11 uses config 1, start time is 120, finish time = 147
# Task 11 uses config 1, start time is 121, finish time = 148
# Task 11 uses config 1, start time is 122, finish time = 149
# Task 11 uses config 1, start time is 123, finish time = 150
# Task 11 uses config 1, start time is 124, finish time = 151
# Task 11 uses config 1, start time is 125, finish time = 152
# Task 11 uses config 1, start time is 126, finish time = 153
# Task 11 uses config 1, start time is 127, finish time = 154
# Task 11 uses config 1, start time is 128, finish time = 155
# Task 11 uses config 1, start time is 129, finish time = 156
# Task 11 uses config 1, start time is 130, finish time = 157
# Task 11 uses config 1, start time is 131, finish time = 158
# Task 11 uses config 1, start time is 132, finish time = 159
# Task 11 uses config 1, start time is 133, finish time = 160
# Task 11 uses config 1, start time is 134, finish time = 161
# Task 11 uses config 1, start time is 135, finish time = 162
# Task 11 uses config 1, start time is 136, finish time = 163
# Task 11 uses config 1, start time is 137, finish time = 164
# Task 11 uses config 1, start time is 138, finish time = 165
# Task 11 uses config 1, start time is 139, finish time = 166
# Task 11 uses config 1, start time is 140, finish time = 167
# Task 11 uses config 1, start time is 141, finish time = 168
# Task 11 uses config 1, start time is 142, finish time = 169
# Task 11 uses config 1, start time is 143, finish time = 170
# Task 11 uses config 1, start time is 144, finish time = 171
# Task 11 uses config 1, start time is 145, finish time = 172
# Task 11 uses config 1, start time is 146, finish time = 173
# Task 11 uses config 1, start time is 147, finish time = 174
# Task 11 uses config 1, start time is 148, finish time = 175
# Task 11 uses config 1, start time is 149, finish time = 176
# Task 11 uses config 1, start time is 150, finish time = 177
# Task 11 uses config 1, start time is 151, finish time = 178
# Task 11 uses config 1, start time is 152, finish time = 179
# Task 11 uses config 1, start time is 153, finish time = 180
# Task 11 uses config 1, start time is 154, finish time = 181
# Task 11 uses config 1, start time is 155, finish time = 182
# Task 11 uses config 1, start time is 156, finish time = 183
# Task 11 uses config 1, start time is 157, finish time = 184
# Task 11 uses config 1, start time is 158, finish time = 185
# Task 11 uses config 1, start time is 159, finish time = 186
# Task 11 uses config 1, start time is 160, finish time = 187
# Task 11 uses config 1, start time is 161, finish time = 188
# Task 11 uses config 1, start time is 162, finish time = 189
# Task 11 uses config 1, start time is 163, finish time = 190
# Task 11 uses config 1, start time is 164, finish time = 191
# Task 11 uses config 1, start time is 165, finish time = 192
# Task 11 uses config 1, start time is 166, finish time = 193
# Task 11 uses config 1, start time is 167, finish time = 194
# Task 11 uses config 1, start time is 168, finish time = 195
# Task 11 uses config 1, start time is 169, finish time = 196
# Task 11 uses config 1, start time is 170, finish time = 197
# Task 11 uses config 1, start time is 171, finish time = 198
# Task 11 uses config 1, start time is 172, finish time = 199
# Task 11 uses config 1, start time is 173, finish time = 200
# Task 11 uses config 1, start time is 174, finish time = 201
# Task 11 uses config 1, start time is 175, finish time = 202
# Task 11 uses config 1, start time is 176, finish time = 203
# Task 11 uses config 1, start time is 177, finish time = 204
# Task 11 uses config 1, start time is 178, finish time = 205
# Task 11 uses config 1, start time is 179, finish time = 206
# Task 11 uses config 1, start time is 180, finish time = 207
# Task 11 uses config 1, start time is 181, finish time = 208
# Task 11 uses config 1, start time is 182, finish time = 209
# Task 11 uses config 1, start time is 183, finish time = 210
# Task 11 uses config 1, start time is 184, finish time = 211
# Task 11 uses config 1, start time is 185, finish time = 212
# Task 11 uses config 1, start time is 186, finish time = 213
# Task 11 uses config 1, start time is 187, finish time = 214
# Task 11 uses config 1, start time is 188, finish time = 215
# Task 11 uses config 1, start time is 189, finish time = 216
# Task 11 uses config 1, start time is 190, finish time = 217
# Task 11 uses config 1, start time is 191, finish time = 218
# Task 11 uses config 1, start time is 192, finish time = 219
# Task 11 uses config 1, start time is 193, finish time = 220
# Excessive output truncated after 524326 bytes.
# Task 11 uses config 1, start time is 194, finish time = 221
# Task 11 uses config 1, start time is 195, finish time = 222
# Task 11 uses config 1, start time is 196, finish time = 223
# Task 11 uses config 1, start time is 197, finish time = 224
# Task 11 uses config 1, start time is 198, finish time = 225
# Task 11 uses config 1, start time is 199, finish time = 226
# Task 11 uses config 1, start time is 200, finish time = 227
# Task 11 uses config 1, start time is 201, finish time = 228
# Task 11 uses config 1, start time is 202, finish time = 229
# Task 11 uses config 1, start time is 203, finish time = 230
# Task 11 uses config 1, start time is 204, finish time = 231
# Task 11 uses config 1, start time is 205, finish time = 232
# Task 11 uses config 1, start time is 206, finish time = 233
# Task 11 uses config 1, start time is 207, finish time = 234
# Task 11 uses config 1, start time is 208, finish time = 235

# %% [markdown]
# ## 4. Discussion of Results ##
#
# Here, you display and discuss the results. Show figures, tables, plots, images, trade-off curves, or whatever else you can think of to best illustrate your results. The discussion should explain what the results mean, and how to interpret them. You should also explain the limitations of your approach/model and how sensitive your results are to the assumptions you made.
#
#  Use plots (see `Plots` examples from class), or you can display results in a table like this:
#
# | Tables        | Are          | Cool  |
# | ------------- |:-------------| -----:|
# | col 3 is      |right-aligned |\$1600 |
# |  colons       | align columns|  \$12 |
# | zebra stripes |    are neat  |   \$1 |
#
# ### 4.A. Feel free to add subsections
#
# #### 4.A.a. or subsubsections

# %% [markdown]
# ## 5. Conclusion ##
#
# Summarize your findings and your results, and talk about at least one possible future direction; something that might be interesting to pursue as a follow-up to your project.

# %% [markdown]
# ## 6. Reference ##

# %% [markdown]
# 1. Kato, Shinpei, et al. "{TimeGraph}:{GPU} Scheduling for {Real-Time}{Multi-Tasking} Environments." 2011 USENIX Annual Technical Conference (USENIX ATC 11). 2011.
# 2. Xu, Kaiqiang, et al. "Design and operation of shared machine learning clusters on campus." Proceedings of the 30th ACM International Conference on Architectural Support for Programming Languages and Operating Systems, Volume 1. 2025.
